# %% [markdown]
# # 量子とは何か？

# %%
# This code is to create the interactive figure
# このコードはインタラクティブな図形を作成するためのものです
from bokeh.events import ButtonClick
from bokeh.layouts import row, column
from bokeh.models import ColumnDataSource, CustomJS, Button, Slider, DataRange1d, LabelSet, RadioButtonGroup, Div
from bokeh.plotting import figure
from bokeh.embed import file_html
from bokeh.resources import CDN
from bokeh.io import output_notebook, show, curdoc
import IPython

# %% [markdown]
# 「量子物理学」は広く使用されている用語ですが、あまり理解されていません。「量子物理学」は「古典」物理学の理論では説明できない実験室での小さなものの振る舞いを説明するために、最初に使用された数学モデルです。 量子論はこの振る舞いを説明し、私たちの世界のより完全な全体像を与えてくれます。 そして以前は説明できなかったこの振る舞いを使用して、不可能と思われていた特定の計算を実行できることに気付きました。 これを量子コンピューティングと呼びます。
#
# 量子コンピューティングは、量子物理学に踏み出す最適な方法です。 量子物理学の核となる概念を最も単純な形に抽出し、物理世界の複雑さを取り除きます。 それでは、いくつかの奇妙な量子現象を発見（そして説明！）して、「量子」が何であるかを味わっていきましょう。

# %% [markdown]
# ## 古典的確率の復習
#
# 量子現象を理解するために、私たちは最初に「古典的な」確率を思い出す必要があります。 ここでの「古典的な」とは、量子より前、つまり学校で習うはずの正規確率ツリーを意味します。 この分野に既に精通している場合は、すぐに読み進めることができます。 それほど精通していない場合でも、心配しないでください。可能な限り最も単純な確率の問題をいくつか取り上げていきます。
#
# ### 確率ツリー
#
# もしかしたら学校で習った確率ツリーを覚えているかもしれません。 アイデアは単純です。図面を使用して、起こりうるすべての不測の事態をマッピングし、発生する確率を計算していきます。
#
# 例えばコインを持っているとしましょう。まず、それをヘッドの状態に置きます。 次に、この公正なコインを投げてそれを見ると、50％の確率で再びヘッドが表示され、50％の確率でテイルが表示されます。 これを次のように確率ツリーにプロットできます。
#
# ![](images/whatis/whatis1.png)
#
# 各枝の終わりに結果を描画し、枝での各発生の確率を描画します。 同様に、テイルの状態で開始してコインを投げた場合、50％の確率でヘッドが表示され、50％の確率でテイルが表示されます。
#
# ![](images/whatis/whatis2.png)
#
# 試してみることでこの動作をテストできます。 物理的にコインを取り出し、何度も実行し、それぞれの結果を記録することができます。 最終的に、結果の約50％がヘッドで50％がテイルであることがわかります。 信頼できる結果を得るには、約500〜1000回のトスで十分です。
#
# ### 実験 #1: シングルコイントス
#
# 下の`Toss Coin`ボタンを押してコイントスをシミュレートし、結果を保存することで、コイントス実験をシミュレートできます。 初期状態を「ヘッド」または「テイル」に変更したり、コインの数（`No. of Coins`）スライダーを増やしたりして、多くの結果をすばやく得ることができます。結果を破棄し、やり直すためには`Reset`を押してください。

# %%
data_labels = ["Heads", "Tails"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# ボタンとスライダーを定義する
tossbtn = Button(label="Toss Coin")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=0)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# コールバックを定義する
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = Math.floor(Math.random() * 2);
            source.data.top[result] += 1;
            resultsHTML.text += [' H ', ' T '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Coin";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Coins";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# コールバックをボタン/スライダーにリンクする
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# レイアウトの作成
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# HTMLを出力
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.2.3.min.js" integrity="sha384-T2yuo9Oe71Cz/I4X9Ac5+gpEa5a8PpJCDlqKYO0CfAuEszu1JrXLl8YugMqYe3sM" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.2.3.min.js" integrity="sha384-98GDGJ0kOMCUMUePhksaQ/GYgB3+NH9h996V88sh3aOiUNX3N+fLXAtry6xctSZ6" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="79412d93-75f3-4fde-9784-a453096e7d2a" data-root-id="1823"></div>
#
#
#
#
#
#         <script type="application/json" id="1896">
#           {"1b47a4a4-3fa1-485f-bb00-8868173c1509":{"roots":{"references":[{"attributes":{"axis_label":"Counts","formatter":{"id":"1826"},"ticker":{"id":"1799"}},"id":"1798","type":"LinearAxis"},{"attributes":{},"id":"1802","type":"ResetTool"},{"attributes":{},"id":"1828","type":"CategoricalTickFormatter"},{"attributes":{"text":"Results:"},"id":"1817","type":"Div"},{"attributes":{},"id":"1826","type":"BasicTickFormatter"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["Heads","Tails"]},"selected":{"id":"1831"},"selection_policy":{"id":"1830"}},"id":"1785","type":"ColumnDataSource"},{"attributes":{"text":""},"id":"1825","type":"Title"},{"attributes":{"source":{"id":"1785"}},"id":"1809","type":"CDSView"},{"attributes":{"args":{"tossbtn":{"id":"1812"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Coin\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Coins\";\n    };\n    "},"id":"1820","type":"CustomJS"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"1820"}]},"start":1,"title":"No. of Coins","value":0},"id":"1813","type":"Slider"},{"attributes":{},"id":"1830","type":"UnionRenderers"},{"attributes":{},"id":"1831","type":"Selection"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1807","type":"VBar"},{"attributes":{"data_source":{"id":"1785"},"glyph":{"id":"1806"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1807"},"selection_glyph":null,"view":{"id":"1809"}},"id":"1808","type":"GlyphRenderer"},{"attributes":{"factors":["Heads","Tails"]},"id":"1788","type":"FactorRange"},{"attributes":{"active":0,"labels":["Heads","Tails"],"name":"Initial State"},"id":"1815","type":"RadioButtonGroup"},{"attributes":{"below":[{"id":"1795"}],"center":[{"id":"1797"},{"id":"1801"},{"id":"1810"}],"left":[{"id":"1798"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"1808"}],"sizing_mode":"scale_width","title":{"id":"1825"},"toolbar":{"id":"1803"},"x_range":{"id":"1788"},"x_scale":{"id":"1791"},"y_range":{"id":"1786"},"y_scale":{"id":"1793"}},"id":"1787","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"1828"},"ticker":{"id":"1796"}},"id":"1795","type":"CategoricalAxis"},{"attributes":{"axis":{"id":"1795"},"ticker":null},"id":"1797","type":"Grid"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"1818","type":"Div"},{"attributes":{"args":{"resultsHTML":{"id":"1818"},"results_label":{"id":"1817"},"source":{"id":"1785"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0.00%'];\n    source.change.emit();\n    resultsHTML.text = \"\";\n    results_label.text = \"Results:\";\n    "},"id":"1821","type":"CustomJS"},{"attributes":{},"id":"1799","type":"BasicTicker"},{"attributes":{"children":[{"id":"1787"},{"id":"1822"}]},"id":"1823","type":"Row"},{"attributes":{},"id":"1796","type":"CategoricalTicker"},{"attributes":{"text":"Initial State:"},"id":"1814","type":"Div"},{"attributes":{"args":{"p":{"id":"1787"},"resultsHTML":{"id":"1818"},"results_label":{"id":"1817"},"s":{"id":"1813"},"source":{"id":"1785"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = Math.floor(Math.random() * 2);\n            source.data.top[result] += 1;\n            resultsHTML.text += [' H ', ' T '][result]\n        }\n        const total_tosses = source.data.top[0] + source.data.top[1];\n        results_label.text = \"Results (\" + total_tosses + \" tosses):\";\n        \n        for (var i = 0; i&lt;2; ++i){\n            const frac = source.data.top[i] / source.data.top.reduce((a, b) =&gt; a + b, 0);\n            source.data.top_percent[i] = (frac*100).toFixed(2) + \"%\";\n        }\n        if (Math.max(...source.data.top) &gt; 22) {\n            p.y_r ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('1896').textContent;
#                   var render_items = [{"docid":"1b47a4a4-3fa1-485f-bb00-8868173c1509","root_ids":["1823"],"roots":{"1823":"79412d93-75f3-4fde-9784-a453096e7d2a"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         }

# %% [markdown]
# ### さらに続けると
#
# 確率ツリーモデルが実験結果を正しく予測しているようです。 さらに進んで、確率ツリーを連鎖させて、一連のイベントの結果を予測することができます。 たとえば、ヘッド状態から始めて、コインを投げてから、_コインをもう一度投げる_ としましょう。何が表示されますか？ ツリーを使ってみてみましょう。
#
# ![](images/whatis/whatis3.png)
#
#
# イベントの各組み合わせの確率を計算するために、枝に沿って乗算していきます。
#
# ![](images/whatis/whatis4.gif)
#
# 次に、結果を合計して、各結果の確率を計算します。
#
# ![](images/whatis/whatis5.gif)
#
# 2回のトス後にヘッドとなる確率は50％であり、テイルとなる確率も50％であることがわかります。
#
# ### 実験 #2: ダブルコイントス
#
# 実験1と同様に、`Toss Coin Twice` ボタンを押して2つのコイントスをシミュレートし、最終結果を保存することで、コイントス実験をシミュレートできます。 初期状態や、`No. of Coins` を変更することで、多くの結果をすばやく得ることができます。結果を破棄し、やり直すためには、`Reset`を押してください。

# %%
data_labels = ["Heads", "Tails"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# ボタンとスライダーを定義する
tossbtn = Button(label="Toss Coin Twice")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=0)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# コールバックを定義する
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = Math.floor(Math.random() * 2);
            source.data.top[result] += 1;
            resultsHTML.text += [' H ', ' T '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Double Tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Coin Twice";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Coins Twice";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# コールバックをボタン/スライダーにリンクする
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# レイアウトの作成
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# HTMLを出力
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.2.3.min.js" integrity="sha384-T2yuo9Oe71Cz/I4X9Ac5+gpEa5a8PpJCDlqKYO0CfAuEszu1JrXLl8YugMqYe3sM" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.2.3.min.js" integrity="sha384-98GDGJ0kOMCUMUePhksaQ/GYgB3+NH9h996V88sh3aOiUNX3N+fLXAtry6xctSZ6" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="32a8f817-6751-4bc8-84f8-3b11b64b9d82" data-root-id="2047"></div>
#
#
#
#
#
#         <script type="application/json" id="2120">
#           {"78791c66-ada1-4686-89e5-1fe3048ed262":{"roots":{"references":[{"attributes":{},"id":"2017","type":"LinearScale"},{"attributes":{"text":""},"id":"2049","type":"Title"},{"attributes":{},"id":"2054","type":"UnionRenderers"},{"attributes":{"axis":{"id":"2022"},"dimension":1,"ticker":null},"id":"2025","type":"Grid"},{"attributes":{"text":"Initial State:"},"id":"2038","type":"Div"},{"attributes":{},"id":"2050","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"2009"}},"id":"2033","type":"CDSView"},{"attributes":{"args":{"p":{"id":"2011"},"resultsHTML":{"id":"2042"},"results_label":{"id":"2041"},"s":{"id":"2037"},"source":{"id":"2009"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = Math.floor(Math.random() * 2);\n            source.data.top[result] += 1;\n            resultsHTML.text += [' H ', ' T '][result]\n        }\n        const total_tosses = source.data.top[0] + source.data.top[1];\n        results_label.text = \"Results (\" + total_tosses + \" Double Tosses):\";\n        \n        for (var i = 0; i&lt;2; ++i){\n            const frac = source.data.top[i] / source.data.top.reduce((a, b) =&gt; a + b, 0);\n            source.data.top_percent[i] = (frac*100).toFixed(2) + \"%\";\n        }\n        if (Math.max(...source.data.top) &gt; 22) {\n            p.y_range.range_padding_units = 'percent';\n            p.y_range.range_padding = 1;\n        } else {\n            p.y_range.range_padding_units = 'absolute';\n            p.y_range.range_padding = 30 - Math.max(...source.data.top);\n        };\n        source.change.emit();\n    "},"id":"2043","type":"CustomJS"},{"attributes":{"below":[{"id":"2019"}],"center":[{"id":"2021"},{"id":"2025"},{"id":"2034"}],"left":[{"id":"2022"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"2032"}],"sizing_mode":"scale_width","title":{"id":"2049"},"toolbar":{"id":"2027"},"x_range":{"id":"2012"},"x_scale":{"id":"2015"},"y_range":{"id":"2010"},"y_scale":{"id":"2017"}},"id":"2011","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"2015","type":"CategoricalScale"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"2044"}]},"start":1,"title":"No. of Coins","value":0},"id":"2037","type":"Slider"},{"attributes":{"data_source":{"id":"2009"},"glyph":{"id":"2030"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2031"},"selection_glyph":null,"view":{"id":"2033"}},"id":"2032","type":"GlyphRenderer"},{"attributes":{"factors":["Heads","Tails"]},"id":"2012","type":"FactorRange"},{"attributes":{"args":{"tossbtn":{"id":"2036"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Coin Twice\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Coins Twice\";\n    };\n    "},"id":"2044","type":"CustomJS"},{"attributes":{},"id":"2023","type":"BasicTicker"},{"attributes":{"args":{"resultsHTML":{"id":"2042"},"results_label":{"id":"2041"},"source":{"id":"2009"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0.00%'];\n    source.change.emit();\n    resultsHTML.text = \"\";\n    results_label.text = \"Results:\";\n    "},"id":"2045","type":"CustomJS"},{"attributes":{"active":0,"labels":["Heads","Tails"],"name":"Initial State"},"id":"2039","type":"RadioButtonGroup"},{"attributes":{"level":"glyph","source":{"id":"2009"},"text":{"field":"top_percent"},"x":{"field":"x"},"x_offset":{"value":-20},"y":{"field":"top"},"y_offset":{"value":12}},"id":"2034","type":"LabelSet"},{"attributes":{"text":"Results:"},"id":"2041","type":"Div"},{"attributes":{},"id":"2020","type":"CategoricalTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2026"}]},"id":"2027","type":"Toolbar"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"2010","type":"DataRange1d"},{"attributes":{"style":{"max- ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('2120').textContent;
#                   var render_items = [{"docid":"78791c66-ada1-4686-89e5-1fe3048ed262","root_ids":["2047"],"roots":{"2047":"32a8f817-6751-4bc8-84f8-3b11b64b9d82"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");

# %% [markdown]
# 十分なトスを行うと、ヘッドまたはテイルを測定するのは等しい確率となり期待通りです。
#
# ## 量子コイン
#
# 古典的なコインの完全な説明ができたところで次は、量子「コイン」を紹介します。 量子コインは「キュービット」と呼ばれています。
#
# キュービットは操作が非常に難しいため、ラボでしか遊べないものです。 長年の科学的および技術的進歩により、今日のキュービットが作成されています。量子コンピューティングを通して学習することで、物理的な複雑さを無視することができます。またキュービットを測定すると2つの状態のうち1つになることを覚えておいてください。 ヘッドとテイルの2つの状態の代わりに、キュービットの2つの状態を0と1と呼びます。
#
# ### 実験 #3: 量子コイントス
#
# 量子コインを試して、どのように動作するかを見てみましょう。 量子トスを行い、コインの状態を測定して記録します。 これは、上記のセクションの古典的なコイントスと同じです。

# %%
data_labels = ["0", "1"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# ボタンとスライダーを定義する
tossbtn = Button(label="Toss Quantum Coin")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=0)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# コールバックを定義する
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = Math.floor(Math.random() * 2);
            source.data.top[result] += 1;
            resultsHTML.text += [' 0 ', ' 1 '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Quantum Tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Quantum Coin";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Quantum Coins";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# コールバックをボタン/スライダーにリンクする
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# レイアウトの作成
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# HTMLを出力
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.2.3.min.js" integrity="sha384-T2yuo9Oe71Cz/I4X9Ac5+gpEa5a8PpJCDlqKYO0CfAuEszu1JrXLl8YugMqYe3sM" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.2.3.min.js" integrity="sha384-98GDGJ0kOMCUMUePhksaQ/GYgB3+NH9h996V88sh3aOiUNX3N+fLXAtry6xctSZ6" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="9141a4d4-f919-48d5-8a59-51543b1d45d9" data-root-id="2159"></div>
#
#
#
#
#
#         <script type="application/json" id="2232">
#           {"4b9229ef-6380-4810-94ff-926e7c31246b":{"roots":{"references":[{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"2154","type":"Div"},{"attributes":{"axis":{"id":"2134"},"dimension":1,"ticker":null},"id":"2137","type":"Grid"},{"attributes":{"text":""},"id":"2161","type":"Title"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"2155"}]},"label":"Toss Quantum Coin"},"id":"2148","type":"Button"},{"attributes":{"args":{"p":{"id":"2123"},"resultsHTML":{"id":"2154"},"results_label":{"id":"2153"},"s":{"id":"2149"},"source":{"id":"2121"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = Math.floor(Math.random() * 2);\n            source.data.top[result] += 1;\n            resultsHTML.text += [' 0 ', ' 1 '][result]\n        }\n        const total_tosses = source.data.top[0] + source.data.top[1];\n        results_label.text = \"Results (\" + total_tosses + \" Quantum Tosses):\";\n        \n        for (var i = 0; i&lt;2; ++i){\n            const frac = source.data.top[i] / source.data.top.reduce((a, b) =&gt; a + b, 0);\n            source.data.top_percent[i] = (frac*100).toFixed(2) + \"%\";\n        }\n        if (Math.max(...source.data.top) &gt; 22) {\n            p.y_range.range_padding_units = 'percent';\n            p.y_range.range_padding = 1;\n        } else {\n            p.y_range.range_padding_units = 'absolute';\n            p.y_range.range_padding = 30 - Math.max(...source.data.top);\n        };\n        source.change.emit();\n    "},"id":"2155","type":"CustomJS"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["0","1"]},"selected":{"id":"2167"},"selection_policy":{"id":"2166"}},"id":"2121","type":"ColumnDataSource"},{"attributes":{},"id":"2164","type":"CategoricalTickFormatter"},{"attributes":{},"id":"2129","type":"LinearScale"},{"attributes":{},"id":"2132","type":"CategoricalTicker"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"2156"}]},"start":1,"title":"No. of Coins","value":0},"id":"2149","type":"Slider"},{"attributes":{"children":[{"id":"2148"},{"id":"2149"},{"id":"2150"},{"id":"2151"},{"id":"2152"},{"id":"2153"},{"id":"2154"}]},"id":"2158","type":"Column"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2138"}]},"id":"2139","type":"Toolbar"},{"attributes":{"data_source":{"id":"2121"},"glyph":{"id":"2142"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2143"},"selection_glyph":null,"view":{"id":"2145"}},"id":"2144","type":"GlyphRenderer"},{"attributes":{"active":0,"labels":["0","1"],"name":"Initial State"},"id":"2151","type":"RadioButtonGroup"},{"attributes":{"args":{"tossbtn":{"id":"2148"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Quantum Coin\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Quantum Coins\";\n    };\n    "},"id":"2156","type":"CustomJS"},{"attributes":{},"id":"2138","type":"ResetTool"},{"attributes":{"level":"glyph","source":{"id":"2121"},"text":{"field":"top_percent"},"x":{"field":"x"},"x_offset":{"value":-20},"y":{"field":"top"},"y_offset":{"value":12}},"id":"2146","type":"LabelSet"},{"attributes":{},"id":"2162","type":"BasicTickFormatter"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"2122","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#BE95FF"},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"2142","type":"VBar"},{"attributes":{},"id":"2166","type":"UnionRenderers"},{"attributes":{},"id":"2127","type":"CategoricalScale"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"2143","type":"VBar"},{"att ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('2232').textContent;
#                   var render_items = [{"docid":"4b9229ef-6380-4810-94ff-926e7c31246b","root_ids":["2159"],"roots":{"2159":"9141a4d4-f919-48d5-8a59-51543b1d45d9"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         }

# %% [markdown]
# 確率ツリーを使用して、量子コインについて説明します。 これは、0の状態から、コイントスで0または1を測定する確率が50-50になるように見えます。古典的なコインで行ったように、これをツリーにプロットしてみましょう。
#
# ![](images/whatis/whatis6.png)

# %%
data_labels = ["0", "1"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# ボタンとスライダーを定義する
tossbtn = Button(label="Toss Quantum Coin")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=1)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# コールバックを定義する
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = Math.floor(Math.random() * 2);
            source.data.top[result] += 1;
            resultsHTML.text += [' 0 ', ' 1 '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Quantum Tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Quantum Coin";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Quantum Coins";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# コールバックをボタン/スライダーにリンクする
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# レイアウトの作成
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# HTMLを出力
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.2.3.min.js" integrity="sha384-T2yuo9Oe71Cz/I4X9Ac5+gpEa5a8PpJCDlqKYO0CfAuEszu1JrXLl8YugMqYe3sM" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.2.3.min.js" integrity="sha384-98GDGJ0kOMCUMUePhksaQ/GYgB3+NH9h996V88sh3aOiUNX3N+fLXAtry6xctSZ6" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="220699fb-c9a0-45d8-bc30-cb9d3188acb6" data-root-id="2271"></div>
#
#
#
#
#
#         <script type="application/json" id="2344">
#           {"ee0327f9-c2ff-4669-9fa9-44013547fd88":{"roots":{"references":[{"attributes":{"axis":{"id":"2243"},"ticker":null},"id":"2245","type":"Grid"},{"attributes":{},"id":"2276","type":"CategoricalTickFormatter"},{"attributes":{},"id":"2278","type":"UnionRenderers"},{"attributes":{"active":1,"labels":["0","1"],"name":"Initial State"},"id":"2263","type":"RadioButtonGroup"},{"attributes":{"data_source":{"id":"2233"},"glyph":{"id":"2254"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2255"},"selection_glyph":null,"view":{"id":"2257"}},"id":"2256","type":"GlyphRenderer"},{"attributes":{"text":"Results:"},"id":"2265","type":"Div"},{"attributes":{},"id":"2241","type":"LinearScale"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"2267"}]},"label":"Toss Quantum Coin"},"id":"2260","type":"Button"},{"attributes":{"children":[{"id":"2235"},{"id":"2270"}]},"id":"2271","type":"Row"},{"attributes":{},"id":"2250","type":"ResetTool"},{"attributes":{},"id":"2239","type":"CategoricalScale"},{"attributes":{"level":"glyph","source":{"id":"2233"},"text":{"field":"top_percent"},"x":{"field":"x"},"x_offset":{"value":-20},"y":{"field":"top"},"y_offset":{"value":12}},"id":"2258","type":"LabelSet"},{"attributes":{"args":{"tossbtn":{"id":"2260"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Quantum Coin\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Quantum Coins\";\n    };\n    "},"id":"2268","type":"CustomJS"},{"attributes":{},"id":"2274","type":"BasicTickFormatter"},{"attributes":{"text":"Initial State:"},"id":"2262","type":"Div"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"2269"}]},"label":"Reset"},"id":"2264","type":"Button"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"2266","type":"Div"},{"attributes":{"source":{"id":"2233"}},"id":"2257","type":"CDSView"},{"attributes":{"formatter":{"id":"2276"},"ticker":{"id":"2244"}},"id":"2243","type":"CategoricalAxis"},{"attributes":{},"id":"2279","type":"Selection"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["0","1"]},"selected":{"id":"2279"},"selection_policy":{"id":"2278"}},"id":"2233","type":"ColumnDataSource"},{"attributes":{"args":{"resultsHTML":{"id":"2266"},"results_label":{"id":"2265"},"source":{"id":"2233"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0.00%'];\n    source.change.emit();\n    resultsHTML.text = \"\";\n    results_label.text = \"Results:\";\n    "},"id":"2269","type":"CustomJS"},{"attributes":{"below":[{"id":"2243"}],"center":[{"id":"2245"},{"id":"2249"},{"id":"2258"}],"left":[{"id":"2246"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"2256"}],"sizing_mode":"scale_width","title":{"id":"2273"},"toolbar":{"id":"2251"},"x_range":{"id":"2236"},"x_scale":{"id":"2239"},"y_range":{"id":"2234"},"y_scale":{"id":"2241"}},"id":"2235","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"2255","type":"VBar"},{"attributes":{"fill_color":{"value":"#BE95FF"},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"2254","type":"VBar"},{"attributes":{"axis_label":"Counts","formatter":{"id":"2274"},"ticker":{"id":"2247"}},"id":"2246","type":"LinearAxis"},{"attributes":{"text":""},"id":"2273","type":"Title"},{"attributes":{"axis":{"id":"2246"},"dimension":1,"ticker":null},"id":"2249","type":"Grid"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"2268"}]},"start":1,"title":"No. of Coins","value":0},"id":"2261","type":"Slider"},{"attributes":{"children":[{"id":"2260"},{"id":"2261"},{"id":"2262"},{"id":"2263"},{"id":"2264"},{"id":"2265"},{"id":"2266"}]},"id":"2270","type":"Column"},{" ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('2344').textContent;
#                   var render_items = [{"docid":"ee0327f9-c2ff-4669-9fa9-44013547fd88","root_ids":["2271"],"roots":{"2271":"220699fb-c9a0-45d8-bc30-cb9d3188acb6"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         }

# %% [markdown]
# 同様に、1の状態から、コイントスにより0または1を測定する確率は50-50になります。確率ツリーは次のようになります。
#
# ![](images/whatis/whatis7.png)
#
# ### 実験 #4: ダブル量子コイントス
#
# これで、量子コインの動作を予測するモデルができました。 優れた科学者のように、新しいシナリオでそれをテストし、正しいか確認したいと思います。 以前と同じようにダブルコイントスを試してみましょう。 古典的なコインと同じように、量子コインのモデルでは、どの状態で開始するかに関係なく、0または1を測定する確率が50-50であると予測しています。
#
# ![](images/whatis/whatis8.png)

# %% [markdown]
# さあ、やってみましょう！ 量子コインを2回投げます。

# %%
data_labels = ["0", "1"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# ボタンとスライダーを定義する
tossbtn = Button(label="Toss Quantum Coin Twice")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=0)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# コールバックを定義する
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label,
                                init_state_radio=init_state_radio), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = init_state_radio.active;
            source.data.top[result] += 1;
            resultsHTML.text += [' 0 ', ' 1 '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Double Quantum Tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Quantum Coin Twice";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Quantum Coins Twice";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# コールバックをボタン/スライダーにリンクする
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# レイアウトの作成
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# HTMLを出力
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.2.3.min.js" integrity="sha384-T2yuo9Oe71Cz/I4X9Ac5+gpEa5a8PpJCDlqKYO0CfAuEszu1JrXLl8YugMqYe3sM" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.2.3.min.js" integrity="sha384-98GDGJ0kOMCUMUePhksaQ/GYgB3+NH9h996V88sh3aOiUNX3N+fLXAtry6xctSZ6" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="4c565cc2-ad99-49ad-86ed-1ca13e841b6f" data-root-id="2383"></div>
#
#
#
#
#
#         <script type="application/json" id="2456">
#           {"986ac8ea-06dc-4141-b7c5-9dc0e2b15c5d":{"roots":{"references":[{"attributes":{"text":"Initial State:"},"id":"2374","type":"Div"},{"attributes":{},"id":"2356","type":"CategoricalTicker"},{"attributes":{},"id":"2391","type":"Selection"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["0","1"]},"selected":{"id":"2391"},"selection_policy":{"id":"2390"}},"id":"2345","type":"ColumnDataSource"},{"attributes":{},"id":"2386","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"2388"},"ticker":{"id":"2356"}},"id":"2355","type":"CategoricalAxis"},{"attributes":{"active":0,"labels":["0","1"],"name":"Initial State"},"id":"2375","type":"RadioButtonGroup"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"2381"}]},"label":"Reset"},"id":"2376","type":"Button"},{"attributes":{},"id":"2362","type":"ResetTool"},{"attributes":{"children":[{"id":"2347"},{"id":"2382"}]},"id":"2383","type":"Row"},{"attributes":{"below":[{"id":"2355"}],"center":[{"id":"2357"},{"id":"2361"},{"id":"2370"}],"left":[{"id":"2358"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"2368"}],"sizing_mode":"scale_width","title":{"id":"2385"},"toolbar":{"id":"2363"},"x_range":{"id":"2348"},"x_scale":{"id":"2351"},"y_range":{"id":"2346"},"y_scale":{"id":"2353"}},"id":"2347","subtype":"Figure","type":"Plot"},{"attributes":{"children":[{"id":"2372"},{"id":"2373"},{"id":"2374"},{"id":"2375"},{"id":"2376"},{"id":"2377"},{"id":"2378"}]},"id":"2382","type":"Column"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"2380"}]},"start":1,"title":"No. of Coins","value":0},"id":"2373","type":"Slider"},{"attributes":{"source":{"id":"2345"}},"id":"2369","type":"CDSView"},{"attributes":{"text":"Results:"},"id":"2377","type":"Div"},{"attributes":{"fill_color":{"value":"#BE95FF"},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"2366","type":"VBar"},{"attributes":{"text":""},"id":"2385","type":"Title"},{"attributes":{"axis_label":"Counts","formatter":{"id":"2386"},"ticker":{"id":"2359"}},"id":"2358","type":"LinearAxis"},{"attributes":{"factors":["0","1"]},"id":"2348","type":"FactorRange"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"2379"}]},"label":"Toss Quantum Coin Twice"},"id":"2372","type":"Button"},{"attributes":{"axis":{"id":"2358"},"dimension":1,"ticker":null},"id":"2361","type":"Grid"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"2378","type":"Div"},{"attributes":{},"id":"2388","type":"CategoricalTickFormatter"},{"attributes":{"axis":{"id":"2355"},"ticker":null},"id":"2357","type":"Grid"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"2346","type":"DataRange1d"},{"attributes":{"data_source":{"id":"2345"},"glyph":{"id":"2366"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2367"},"selection_glyph":null,"view":{"id":"2369"}},"id":"2368","type":"GlyphRenderer"},{"attributes":{"args":{"tossbtn":{"id":"2372"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Quantum Coin Twice\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Quantum Coins Twice\";\n    };\n    "},"id":"2380","type":"CustomJS"},{"attributes":{},"id":"2390","type":"UnionRenderers"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2362"}]},"id":"2363","type":"Toolbar"},{"attributes":{},"id":"2359","type":"BasicTicker"},{"attributes":{},"id":"2353","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"2367","type":"VBar"},{"attributes":{"args":{"init_state_radio":{"id":"2375"},"p":{"id":"2347"},"resultsHTML":{"id":"2378"},"resu ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('2456').textContent;
#                   var render_items = [{"docid":"986ac8ea-06dc-4141-b7c5-9dc0e2b15c5d","root_ids":["2383"],"roots":{"2383":"4c565cc2-ad99-49ad-86ed-1ca13e841b6f"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS librar

# %% [markdown]
# うーん…これは予想外の結果です。 初期状態を1に設定するとどうなるか見てみましょう。

# %%
data_labels = ["0", "1"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# ボタンとスライダーを定義する
tossbtn = Button(label="Toss Quantum Coin Twice")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=1)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# コールバックを定義する
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label,
                                init_state_radio=init_state_radio), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = init_state_radio.active;
            source.data.top[result] += 1;
            resultsHTML.text += [' 0 ', ' 1 '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Quantum Tosses)";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Quantum Coin Twice";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Quantum Coins Twice";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# コールバックをボタン/スライダーにリンクする
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# レイアウトの作成
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# HTMLを出力
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.2.3.min.js" integrity="sha384-T2yuo9Oe71Cz/I4X9Ac5+gpEa5a8PpJCDlqKYO0CfAuEszu1JrXLl8YugMqYe3sM" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.2.3.min.js" integrity="sha384-98GDGJ0kOMCUMUePhksaQ/GYgB3+NH9h996V88sh3aOiUNX3N+fLXAtry6xctSZ6" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="2dfcff5d-5b48-4365-885f-f3f34e44608a" data-root-id="2495"></div>
#
#
#
#
#
#         <script type="application/json" id="2568">
#           {"191c5fd9-d4ac-4be2-8d3a-dbe27f9c1b17":{"roots":{"references":[{"attributes":{"factors":["0","1"]},"id":"2460","type":"FactorRange"},{"attributes":{"active":1,"labels":["0","1"],"name":"Initial State"},"id":"2487","type":"RadioButtonGroup"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2474"}]},"id":"2475","type":"Toolbar"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"2458","type":"DataRange1d"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["0","1"]},"selected":{"id":"2503"},"selection_policy":{"id":"2502"}},"id":"2457","type":"ColumnDataSource"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"2493"}]},"label":"Reset"},"id":"2488","type":"Button"},{"attributes":{"axis_label":"Counts","formatter":{"id":"2498"},"ticker":{"id":"2471"}},"id":"2470","type":"LinearAxis"},{"attributes":{"args":{"tossbtn":{"id":"2484"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Quantum Coin Twice\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Quantum Coins Twice\";\n    };\n    "},"id":"2492","type":"CustomJS"},{"attributes":{},"id":"2468","type":"CategoricalTicker"},{"attributes":{},"id":"2502","type":"UnionRenderers"},{"attributes":{"children":[{"id":"2484"},{"id":"2485"},{"id":"2486"},{"id":"2487"},{"id":"2488"},{"id":"2489"},{"id":"2490"}]},"id":"2494","type":"Column"},{"attributes":{},"id":"2503","type":"Selection"},{"attributes":{"text":""},"id":"2497","type":"Title"},{"attributes":{"source":{"id":"2457"}},"id":"2481","type":"CDSView"},{"attributes":{"axis":{"id":"2470"},"dimension":1,"ticker":null},"id":"2473","type":"Grid"},{"attributes":{"fill_color":{"value":"#BE95FF"},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"2478","type":"VBar"},{"attributes":{},"id":"2474","type":"ResetTool"},{"attributes":{"level":"glyph","source":{"id":"2457"},"text":{"field":"top_percent"},"x":{"field":"x"},"x_offset":{"value":-20},"y":{"field":"top"},"y_offset":{"value":12}},"id":"2482","type":"LabelSet"},{"attributes":{"children":[{"id":"2459"},{"id":"2494"}]},"id":"2495","type":"Row"},{"attributes":{"below":[{"id":"2467"}],"center":[{"id":"2469"},{"id":"2473"},{"id":"2482"}],"left":[{"id":"2470"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"2480"}],"sizing_mode":"scale_width","title":{"id":"2497"},"toolbar":{"id":"2475"},"x_range":{"id":"2460"},"x_scale":{"id":"2463"},"y_range":{"id":"2458"},"y_scale":{"id":"2465"}},"id":"2459","subtype":"Figure","type":"Plot"},{"attributes":{"axis":{"id":"2467"},"ticker":null},"id":"2469","type":"Grid"},{"attributes":{},"id":"2463","type":"CategoricalScale"},{"attributes":{},"id":"2498","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"2457"},"glyph":{"id":"2478"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2479"},"selection_glyph":null,"view":{"id":"2481"}},"id":"2480","type":"GlyphRenderer"},{"attributes":{"text":"Results:"},"id":"2489","type":"Div"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"2490","type":"Div"},{"attributes":{},"id":"2471","type":"BasicTicker"},{"attributes":{"args":{"resultsHTML":{"id":"2490"},"results_label":{"id":"2489"},"source":{"id":"2457"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0.00%'];\n    source.change.emit();\n    resultsHTML.text = \"\";\n    results_label.text = \"Results:\";\n    "},"id":"2493","type":"CustomJS"},{"attributes":{"args":{"init_state_radio":{"id":"2487"},"p":{"id":"2459"},"resultsHTML":{"id":"2490"},"results_label":{"id":"2489"},"s":{"id":"2485"},"source":{"id":"2457"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = init_state_radio.active;\n            source.data.top[result] += 1;\n            re ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('2568').textContent;
#                   var render_items = [{"docid":"191c5fd9-d4ac-4be2-8d3a-dbe27f9c1b17","root_ids":["2495"],"roots":{"2495":"2dfcff5d-5b48-4365-885f-f3f34e44608a"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is mis

# %% [markdown]
# 私たちの予測とはまったく一致しません！ このモデルでは説明できません！ これは、物理学者が20世紀初頭に遭遇したのと同じ問題です。 答えを探すことで、量子物理学の発展につながりました。量子コイントスを説明するためにその答えを使ってみましょう。
#
# ## 量子モデル
#
# 要するに、量子論は負の数の確率論です。
#
# これは何を意味するのでしょうか？ 意味のない負の確率を持つことはできません。 これに対応するために、_振幅_ と呼ばれる新しい量を使用し、代わりにこれらをツリーにプロットします。 負の確率を持つことはできず、すべての確率を合計して1にする必要があるという事実のため、数学的なトリックを使用します。振幅を2乗して確率を計算します。
#
# 例を見てみましょう。 単一量子コイントスの振幅ツリーは次のようになります。
#
# ![](images/whatis/whatis9.png)
#
# 状態0から開始して、量子コイントスが両方の結果に等しい振幅を割り当てることがわかります。 これらの振幅を2乗すると、0または1を測定する正しい確率が得られます（50-50の確率）。 振幅が $\sqrt{\tfrac{1}{2}}$ であることをどうやって知りましたか？ こうすると正しい答えを得られるからです！
#
# 状態1から始めると、振幅ツリーは異なります。
#
# ![](images/whatis/whatis10.png)
#
# 1の結果の振幅に最初の負の数が現れています。 振幅を二乗して確率を計算すると、この負の符号が消え（負の数×負の値は正であることを思い出してください）、上記を測定すると50-50の確率となります。 興味深い結果は、これらを連鎖させるとおきます。

# %% [markdown]
# ## ダブル量子コイントスの説明
#
# 古典的な確率と同様に、分岐に沿って振幅を乗算して、各結果の振幅を計算します。
#
# ![](images/whatis/whatis11.gif)
#
# そして、各結果を測定する確率を計算するために、これらの振幅を合計し、次にそれらを二乗します。
#
# ![](images/whatis/whatis12.gif)
#
# 状態1のコイン（キュービット）を見つける振幅が互いに打ち消し合っていることがわかります。これを干渉と呼びます。 初期状態が1のときにこのモデルが機能することを確かめてください。

# %% [markdown]
# ## 量子コンピューティングとは何か？
#
# 干渉効果は有用であることがわかりました。 量子コイントスなどの操作を組み合わせて、より効率的なアルゴリズムを構築できます。 これらのアルゴリズムは、干渉効果を使用して、間違った答えをすばやくキャンセルし、正しい答えを測定する可能性を高くすることができます。 これが量子コンピューティングの背後にある考え方です。
